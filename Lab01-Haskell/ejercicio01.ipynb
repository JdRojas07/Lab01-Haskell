-- %%
[1,2,3]++[4,5]
-- Out:
-- [1,2,3]++[4,5] :: forall {a}. Num a => [a]

-- %%
 :t True
 :t "Hola mundo"
 :t [1,2,3]
-- Out:
-- True :: Bool
-- "Hola mundo" :: String
-- [1,2,3] :: forall {a}. Num a => [a]

-- %%
doble :: Int -> Int
doble x=x*2
doble 2
-- Out:
-- 4

-- %%
esMayorEdad :: Int -> Bool
esMayorEdad x=x>=18
esMayorEdad 18
-- Out:
-- True

-- %%
areaCirculo :: Float -> Float
